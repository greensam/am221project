# %%
# %matplotlib inline 

import requests
from bs4 import BeautifulSoup
from bs4 import NavigableString
import pandas as pd
import StringIO
import urllib
from datetime import date, datetime, timedelta
import itertools
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches
from scipy.stats.stats import pearsonr
import math
import sys

from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from sklearn import metrics
from sklearn.cross_validation import cross_val_score

plt.style.use('ggplot')

# %%
# Simple lambda function
def split(x, num):
    return int(x.split('-')[num])

# Write a function that scrapes the team trend graph for each game
def ncaatrendgraph(gameid):

    # Scrape the reference team page
    url = 'http://espn.go.com/mens-college-basketball/playbyplay?gameId=' + str(gameid)
    html = urllib.urlopen(url)
    soup = BeautifulSoup(html, "html.parser") 

    # Identify which team is which from the basic page
    teams = soup.find_all('div', {'class', "team-container"})

    away = str(teams[0].find('span', {'class', 'long-name'}).contents[0]).split(';')[0]
    home = str(teams[1].find('span', {'class', 'long-name'}).contents[0]).split(';')[0]

    # # Run through the table and get all the relevant events from that quarter
    qes = []
    tps = len(soup.find_all('table'))-1
    for num in range(1,tps):
        for item in soup.find_all('table')[num].find_all('tr')[1:]:
            event = []
            for td in item.find_all('td'):
                if len(td.contents) > 0:
                    if 'img' in str(td.contents[0]):
                        event.append(str(td.contents[0]['src']).split('/')[-1].split('.')[0].upper())
                    else:
                        if ':' in str(td.contents[0]):
                            if num > 2:
                                minutes = 4-int(td.contents[0].split(':')[0]) + 40 + ((num-3)*5)
                            else:
                                minutes = 19-int(td.contents[0].split(':')[0]) +((num-1)*20)
                            seconds = 60-int(td.contents[0].split(':')[1])

                            # Make an adjustment for exact minute calculations
                            if seconds == 60:
                                minutes = minutes + 1
                                seconds = 0

                            event.append(minutes)
                            event.append(seconds)
                        else:
                            event.append(str(td.contents[0]))
            qes.append(event)

    # Make this data into a Dataframe
    bsd = pd.DataFrame(qes, columns = ['Minutes', 'Seconds', 'Team', 'Event', 'Score'])
    bsd[away] = bsd['Score'].apply(lambda x: split(x, 0))
    bsd[home] = bsd['Score'].apply(lambda x: split(x, 1))
    bsd = bsd.drop('Score', 1)

    # # Write a quick function converting the minutes and seconds to a percentage
    if (tps) == 3:
        numminutes = 40
    else:
        numminutes = 40 + 5*(tps-3)
    lengame = numminutes*60.0
    bsd['PercDone'] = [float(100*round((mins*60+sec)/lengame,4)) for (mins, sec) in zip(bsd['Minutes'], bsd['Seconds'])]
    return bsd

# %%
# Write a function that processes the events that happen during this period
"""
Gamedata: The dataframe containing all the data above
Start: The time at which you'd like to start looking (%H:%M, ex. 7:20 (EST))
Finish: The time at which you'd like to stop looking (see above)
"""
def gamevents(gamedata, start, finish, begin, end):
    start_conv = datetime.strptime(start, '%H:%M')
    finish_conv = datetime.strptime(finish, '%H:%M')
    
    # Make quick sanity checks
    if start_conv < begin:
        start_conv = begin
    if finish_conv > end:
        finish_conv = end
    
    # Check where each event is in relation to halftime
    sloc, endloc = 0, 0
    htbegin = begin + timedelta(0, (end-begin).seconds/2 - lenhalf/2)
    htend = begin + timedelta(0,(end-begin).seconds/2 + lenhalf/2)
    if start_conv > htend:
        sloc = 1
    if finish_conv > htend:
        endloc = 1
        
    # Assume for now that both are on the same side of halftime
    if endloc == 0:
        ttb1, ttb2 = (start_conv - begin).seconds, (finish_conv - begin).seconds
        perc1, perc2 = round(100*(1.0*ttb1)/(2*(htbegin-begin).seconds),2), round(100*(1.0*ttb2)/(2*(htbegin-begin).seconds),2)
    elif endloc == 1:
        ttb1, ttb2 = (start_conv - htend).seconds, (finish_conv - htend).seconds
        perc1, perc2 = round(100*(1.0*ttb1)/(end-htend).seconds,2)+50, round(100*(1.0*ttb2)/(end-htend).seconds,2)+50
    
    # Grab the data from the gamedata
    return gdata[(gdata['PercDone'] > perc1) & (gdata['PercDone'] < perc2)]

# %%
"""
Large function that will return to you the relevant game events and then a list of tweets (with their times) 
from the time period that you specify. Currently works by submitting actual times.

Inputs:
gp1: The first game participant
gp2: The second game participant
tp1: Beginning of time period (%H:%M, ex. 7:20), measured by EST
tp2: End of time period

Outputs:
dt1: Dataframe containing all the game events from that period 
dt2: Dataframe containing the tweets from that period
"""

def databytime(gp1, gp2, tp1, tp2):
    
    # Get the important metadata and define a useful constant
    gmdat = pd.read_csv("GameMetadata.csv")
    metadat = gmdat[((gmdat['Team1'] == gp1) | (gmdat['Team1'] == gp2)) & ((gmdat['Team2'] == gp1) | (gmdat['Team2'] == gp2))]
    eid = metadat['espn_id'].iloc[0]
    begin, end = datetime.strptime(metadat['Start'].iloc[0], '%H:%M'), datetime.strptime(metadat['End'].iloc[0], '%H:%M')
    lenhalf = 20*60
    
    # Grab the game data for the time period
    gdata = ncaatrendgraph(eid)
    dt1 = gamevents(gdata, tp1, tp2, begin, end)
    
    # Grab the relevant data from the twitter file
    fname = metadat['Filename'].iloc[0]
    tweets =  pd.read_csv(fname)
    tweets['time_chg'] = tweets['time'].apply(lambda x: x.split(' ')[3])
    
    indices = []
    for num in range(0, len(tweets['time_chg'])):
        tweetstamp = datetime.strptime(tweets['time_chg'].iloc[num], "%H:%M:%S") - timedelta(hours=4)
        if (tweetstamp > begin) and (tweetstamp < end):
            if (tweetstamp > datetime.strptime(tp1, '%H:%M')) and (tweetstamp < datetime.strptime(tp2, '%H:%M')):
                indices.append(num)
    dt2 = tweets[tweets.index.isin(indices)]
    
    return dt1, dt2

# %%
samp1, samp2 = databytime('Virginia', 'Syracuse', '18:10', '18:20')

# %%
samp1
# Out:
#     Minutes  Seconds Team                                              Event  \
# 1         0       24  183           Trevor Cooney missed Three Point Jumper.
# 2         0       24  183              Malachi Richardson Offensive Rebound.
# 3         0       31  183                       Malachi Richardson Turnover.
# 4         0       45  258         Malcolm Brogdon missed Three Point Jumper.
# 5         0       45  183              Malachi Richardson Defensive Rebound.
# 6         1        9  183                     Michael Gbinije missed Jumper.
# 7         1        9  258                             Malcolm Brogdon Block.
# 8         1        9  258                London Perrantes Defensive Rebound.
# 9         1       22  258        London Perrantes missed Three Point Jumper.
# 10        1       22  183                 Michael Gbinije Defensive Rebound.
# 11        1       30  183                        Tyler Roberson missed Dunk.
# 12        1       30  258                London Perrantes Defensive Rebound.
# 13        1       40  258                          Malcolm Brogdon Turnover.
# 14        1       40  183                               Trevor Cooney Steal.
# 15        1       46  183  Michael Gbinije made Layup. Assisted by Trevor...
# 16        2        7  183                        Foul on Malachi Richardson.
# 17        2        7  258                      Anthony Gill made Free Throw.
# 18        2        7  258                      Anthony Gill made Free Throw.
# 19        2       33  183         Michael Gbinije missed Three Point Jumper.
# 20        2       33  183                  Tyler Roberson Offensive Rebound.
# 21        2       38  183                          Tyler Roberson made Dunk.
# 22        2       58  258        London Perrantes missed Three Point Jumper.
# 23        2       58  258                        Virginia Offensive Rebound.
# 24        3        6  258                           Devon Hall missed Layup.
# 25        3        6  183              Malachi Richardson Defensive Rebound.
# 26        3       22  183                          Michael Gbinije Turnover.
# 27        3       22  258                             Malcolm Brogdon Steal.
# 28        3       43  258                      Isaiah Wilkins missed Jumper.
# 29        3       43  183                 Michael Gbinije Defensive Rebound.
# 30        4        3  183                       Malachi Richardson Turnover.
# 31        4        3  258                                Anthony Gill Steal.
# 32        4        6  258                             Anthony Gill Turnover.
# 33        4        6  183                               Trevor Cooney Steal.
#
#     Syracuse  Virginia  PercDone
# 1          0         0      1.00
# 2          0         0      1.00
# 3          0         0      1.29
# 4          0         0      1.87
# 5          0         0      1.87
# 6          0         0      2.88
# 7          0         0      2.88
# 8          0         0      2.88
# 9          0         0      3.42
# 10         0         0      3.42
# 11         0         0      3.75
# 12         0         0      3.75
# 13         0         0      4.17
# 14         0         0      4.17
# 15         2         0      4.42
# 16         2         0      5.29
# 17         2         1      5.29
# 18         2         2      5.29
# 19         2         2      6.38
# 20         2         2      6.38
# 21         4         2      6.58
# 22         4         2      7.42
# 23         4         2      7.42
# 24         4         2      7.75
# 25         4         2      7.75
# 26         4         2      8.42
# 27         4         2      8.42
# 28         4         2      9.29
# 29         4         2      9.29
# 30         4         2     10.13
# 31         4         2     10.13
# 32         4         2     10.25
# 33         4         2     10.25

# %%
samp2
# Out:
#                                                    text  \
# 1999  RT @fullcourtprez: Time to watch 2-3 zone for ...
# 2000  Malachi scored 23 points in the regular season...
# 2001  Almost time for tip off between #UVA and #Syra...
# 2002  #UVA looking for first Final 4 since this guy ...
# 2003  We are set here in #Chicago!!!! #Syracuse #Vir...
# 2004                               Go cavaliers go #UVA
# 2005  Syracuse Horns #1 - FastModel Sports https://t...
# 2006                                            #GoHoos
# 2007  .@BrentAxeMedia I like Boehiem's suit tonight....
# 2008  RT @Cuse_MBB: Halftime stats\r\n#CuseMode #Mar...
# 2009  RT @Cuse_MBB: The Orange starting 5\r\n#CuseMo...
# 2010  #CuseMode #CuseNation #BleedOrange #BeatVirgin...
# 2011  It's time another #Elite8 game to determine a ...
# 2012  RT @DP_Sports: Almost time for tip off between...
# 2013  Let’s do this @UVAMensHoops! I want to go to H...
# 2014                       Game time!! Let's go #UVA 🏀
# 2015  I graduated from Cuse 10 years ago which makes...
# 2016  Ya listos para #Virginia y #Syracuse X #ESPN3 ...
# 2017                        Game time #CuseMode #Elite8
# 2018                              #DoIt4Biden #CuseMode
# 2019  Available qs 55$ hh 90$ hr 150$ fun as well sy...
# 2020                             Here we go!! #CuseMode
# 2021  Day two of the #Elite8 is underway. Up first i...
# 2022  RT @Cuse_MBB: The Orange starting 5\r\n#CuseMo...
# 2023  (1) #Virginia vs. (10) #Syracuse have tipped o...
# 2024    Syracuse gotta win this #Syracuse #MarchMadness
# 2025                 #Syracuse game! lets gooooo! #ncaa
# 2026  One win from an improbable Final 4.  Let's Go ...
# 2027                                     #UVA #GOHOOSGO
# 2028  I should be playing in the elite 8 game tonigh...
# ...                                                 ...
# 2408           RT @UVaHooCrew: It's Tobey Time! #GoHoos
# 2409  #Syracuse 4, @UVAMensHoops 2 w/1546 left. Team...
# 2410  Let's go #Cuse!  #CuseMode #MarchMadness #Oran...
# 2411  RT @GottliebShow: #UVA - easy. Fatigue &amp; F...
# 2412  RT @kimmymittens: noww it's your turn boys🍊🍊...
# 2413  RT @TheUVAFool: After a birdie on the 18th to ...
# 2414  #UVA's players are already back on the court, ...
# 2415  Gotta get Lyndon in soon cause Gill is even pa...
# 2416  YOU DID IT! ENTER TO WIN! $3,500 CASH!!! #USA ...
# 2417  RT @KendallRogersD1: After losing the series o...
# 2418  RT @GregoryLee757: #UVA vs Cuse is like watchi...
# 2419  15:46 1H #Syracuse up 4-2 on #UVA- teams a com...
# 2420  RT @Cuse_MBB: The Orange starting 5\r\n#CuseMo...
# 2421  RT @UVAMensHoops: #UVA starters vs. @Cuse_MBB:...
# 2422  Let's see how Virginia's offense run against t...
# 2423  With a little over 4min played, Frank Howard &...
# 2424  RT @ParisaMichelle: How is this the same team ...
# 2425  We are watching! @Cuse_MBB @Cuse #Elite8  goin...
# 2426  RT @KendallRogersD1: After losing the series o...
# 2427  Turnover City here in opening minutes of #Syra...
# 2428  [Rivals] The Latest: Virginia beat Syracuse in...
# 2429  RT @Cuse_MBB: .@TRoberson21 with the slam off ...
# 2430  Come on Cuse lets get this W! #CuseMode  #Cuse...
# 2431  RT @UVaHooCrew: "If you want to go fast, go al...
# 2432  RT @fullcourtprez: Time to watch 2-3 zone for ...
# 2433  RT @Cuse_MBB: The Orange starting 5\r\n#CuseMo...
# 2434  RT @ccarlsononSU: Louis Orr, Tyler Ennis, C.J....
# 2435    #GoHoos Settle in and take charge of this game!
# 2436  Let's Go Cuse! #MarchMadness #Syracuse #SYRvsU...
# 2437           RT @UVaHooCrew: It's Tobey Time! #GoHoos
#
#                                 time  time_chg
# 1999  Sun Mar 27 22:10:01 +0000 2016  22:10:01
# 2000  Sun Mar 27 22:10:01 +0000 2016  22:10:01
# 2001  Sun Mar 27 22:10:03 +0000 2016  22:10:03
# 2002  Sun Mar 27 22:10:03 +0000 2016  22:10:03
# 2003  Sun Mar 27 22:10:04 +0000 2016  22:10:04
# 2004  Sun Mar 27 22:10:06 +0000 2016  22:10:06
# 2005  Sun Mar 27 22:10:06 +0000 2016  22:10:06
# 2006  Sun Mar 27 22:10:08 +0000 2016  22:10:08
# 2007  Sun Mar 27 22:10:09 +0000 2016  22:10:09
# 2008  Sun Mar 27 22:10:11 +0000 2016  22:10:11
# 2009  Sun Mar 27 22:10:14 +0000 2016  22:10:14
# 2010  Sun Mar 27 22:10:15 +0000 2016  22:10:15
# 2011  Sun Mar 27 22:10:16 +0000 2016  22:10:16
# 2012  Sun Mar 27 22:10:18 +0000 2016  22:10:18
# 2013  Sun Mar 27 22:10:18 +0000 2016  22:10:18
# 2014  Sun Mar 27 22:10:19 +0000 2016  22:10:19
# 2015  Sun Mar 27 22:10:19 +0000 2016  22:10:19
# 2016  Sun Mar 27 22:10:20 +0000 2016  22:10:20
# 2017  Sun Mar 27 22:10:20 +0000 2016  22:10:20
# 2018  Sun Mar 27 22:10:21 +0000 2016  22:10:21
# 2019  Sun Mar 27 22:10:22 +0000 2016  22:10:22
# 2020  Sun Mar 27 22:10:24 +0000 2016  22:10:24
# 2021  Sun Mar 27 22:10:24 +0000 2016  22:10:24
# 2022  Sun Mar 27 22:10:26 +0000 2016  22:10:26
# 2023  Sun Mar 27 22:10:29 +0000 2016  22:10:29
# 2024  Sun Mar 27 22:10:29 +0000 2016  22:10:29
# 2025  Sun Mar 27 22:10:32 +0000 2016  22:10:32
# 2026  Sun Mar 27 22:10:33 +0000 2016  22:10:33
# 2027  Sun Mar 27 22:10:35 +0000 2016  22:10:35
# 2028  Sun Mar 27 22:10:35 +0000 2016  22:10:35
# ...                              ...       ...
# 2408  Sun Mar 27 22:19:03 +0000 2016  22:19:03
# 2409  Sun Mar 27 22:19:03 +0000 2016  22:19:03
# 2410  Sun Mar 27 22:19:03 +0000 2016  22:19:03
# 2411  Sun Mar 27 22:19:04 +0000 2016  22:19:04
# 2412  Sun Mar 27 22:19:05 +0000 2016  22:19:05
# 2413  Sun Mar 27 22:19:10 +0000 2016  22:19:10
# 2414  Sun Mar 27 22:19:12 +0000 2016  22:19:12
# 2415  Sun Mar 27 22:19:13 +0000 2016  22:19:13
# 2416  Sun Mar 27 22:19:13 +0000 2016  22:19:13
# 2417  Sun Mar 27 22:19:13 +0000 2016  22:19:13
# 2418  Sun Mar 27 22:19:20 +0000 2016  22:19:20
# 2419  Sun Mar 27 22:19:23 +0000 2016  22:19:23
# 2420  Sun Mar 27 22:19:33 +0000 2016  22:19:33
# 2421  Sun Mar 27 22:19:36 +0000 2016  22:19:36
# 2422  Sun Mar 27 22:19:40 +0000 2016  22:19:40
# 2423  Sun Mar 27 22:19:40 +0000 2016  22:19:40
# 2424  Sun Mar 27 22:19:44 +0000 2016  22:19:44
# 2425  Sun Mar 27 22:19:44 +0000 2016  22:19:44
# 2426  Sun Mar 27 22:19:46 +0000 2016  22:19:46
# 2427  Sun Mar 27 22:19:47 +0000 2016  22:19:47
# 2428  Sun Mar 27 22:19:47 +0000 2016  22:19:47
# 2429  Sun Mar 27 22:19:50 +0000 2016  22:19:50
# 2430  Sun Mar 27 22:19:50 +0000 2016  22:19:50
# 2431  Sun Mar 27 22:19:51 +0000 2016  22:19:51
# 2432  Sun Mar 27 22:19:52 +0000 2016  22:19:52
# 2433  Sun Mar 27 22:19:54 +0000 2016  22:19:54
# 2434  Sun Mar 27 22:19:55 +0000 2016  22:19:55
# 2435  Sun Mar 27 22:19:55 +0000 2016  22:19:55
# 2436  Sun Mar 27 22:19:57 +0000 2016  22:19:57
# 2437  Sun Mar 27 22:19:59 +0000 2016  22:19:59
#
# [439 rows x 3 columns]
