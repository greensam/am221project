# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from IPython.display import display
import csv
from dateutil import parser
import pytz

# %%
fnames = pd.read_csv('separated/gameslist.csv').ix[:,0]
gamedatadict = {}

for game in fnames:
    df = pd.read_csv('separated/{0}'.format(game), encoding='utf-8', error_bad_lines=False)
    try:
        df['time'] = df['time'].apply(lambda x:pytz.utc.localize(parser.parse(x)))
        df.index = df['time']
        gamedatadict[game] = df
    except Exception as e:
        print e
        print game
        continue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-25e0b419070f> in <module>()
# ----> 1 fnames = pd.read_csv('separated/gameslist.csv').ix[:,0]
#       2 gamedatadict = {}
#       3
#       4 for game in fnames:
#       5     df = pd.read_csv('separated/{0}'.format(game), encoding='utf-8', error_bad_lines=False)
#
# NameError: name 'pd' is not defined

# %%
def by_minute_plot(gamefile):
    df = gamedatadict[gamefile]
    grouped = df.groupby(df.index.map(lambda t: t.minute)).count()
    plt.plot(grouped)

# %%
plt.figure()
for game in gamedatadict.keys():
    by_minute_plot(game)

plt.suptitle('Time Series of Tweet Volumes by Minute')
plt.xlabel('Time')
plt.ylabel('# Tweets')
plt.savefig('milestone2/tweetvolues.pdf')
